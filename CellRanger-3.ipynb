# %% [markdown]
# # **Preprocessing - Cell Ranger**

# %% [markdown]
# **Installing the SRA toolkit, in order to make use of fastqdump**

# %%
wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
# Out:
# --2024-03-06 10:29:09--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 2607:f220:41e:250::12, 2607:f220:41e:250::13, 130.14.250.12, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|2607:f220:41e:250::12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93494971 (89M) [application/x-gzip]
# Saving to: ‘sratoolkit.current-centos_linux64.tar.gz’
#
# sratoolkit.current- 100%[===================>]  89.16M  21.1MB/s    in 4.4s
#
# 2024-03-06 10:29:14 (20.2 MB/s) - ‘sratoolkit.current-centos_linux64.tar.gz’ saved [93494971/93494971]

# %%
tar -vxzf sratoolkit.current-centos_linux64.tar.gz
# Out:
# sratoolkit.3.1.0-centos_linux64/
# sratoolkit.3.1.0-centos_linux64/README.md
# sratoolkit.3.1.0-centos_linux64/README-vdb-config
# sratoolkit.3.1.0-centos_linux64/schema/
# sratoolkit.3.1.0-centos_linux64/schema/vdb/
# sratoolkit.3.1.0-centos_linux64/schema/vdb/vdb.vschema
# sratoolkit.3.1.0-centos_linux64/schema/vdb/built-in.vschema
# sratoolkit.3.1.0-centos_linux64/schema/insdc/
# sratoolkit.3.1.0-centos_linux64/schema/insdc/insdc.vschema
# sratoolkit.3.1.0-centos_linux64/schema/insdc/sra.vschema
# sratoolkit.3.1.0-centos_linux64/schema/insdc/seq.vschema
# sratoolkit.3.1.0-centos_linux64/schema/sra/
# sratoolkit.3.1.0-centos_linux64/schema/sra/abi.vschema
# sratoolkit.3.1.0-centos_linux64/schema/sra/pevents.vschema
# sratoolkit.3.1.0-centos_linux64/schema/sra/generic-fastq.vschema
# sratoolkit.3.1.0-centos_linux64/schema/sra/454.vschema
# sratoolkit.3.1.0-centos_linux64/schema/sra/pacbio.vschema
# sratoolkit.3.1.0-centos_linux64/schema/sra/illumina.vschema
# ...

# %% [markdown]
# For convenience (and to show you where the binaries are) append the path to the binaries to your PATH environment variable:

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger
ls
# Out:
# cellranger	  refdata-gex-mm10-2020-A	   T1  T4
# cellranger-7.2.0  sratoolkit.3.1.0-centos_linux64  T2  T5

# %%
pwd
# Out:
# /vsc-hard-mounts/leuven-data/345/vsc34524/MasterThesis

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger/
ls
# Out:
# cellranger	  refdata-gex-mm10-2020-A
# cellranger-7.2.0  sratoolkit.3.1.0-centos_linux64

# %% [markdown]
# # **Download the data**
# using SRA toolkit

# %%
export PATH=$PATH:$PWD/sratoolkit.3.1.0-centos_linux64/bin

# %%
#go to all_cell_ranger file first. 
which fastq-dump #Verify that the binaries will be found by the shell:
# Out:
# /lustre1/project/stg_00079/students/soniya/all_cell_ranger/sratoolkit.3.1.0-centos_linux64/bin/fastq-dump

# %%
mkdir fastq_files_test #make directory to store fastq files
ls
# Out:
# mkdir: cannot create directory ‘fastq_files_test’: File exists
# cellranger-7.2.0	    refdata-gex-mm10-2020-A
# cellranger-7.2.0.tar.gz     refdata-gex-mm10-2020-A.tar.gz
# data			    results
# fastq_files_test	    sratoolkit.3.1.0-centos_linux64
# Miniforge3-Linux-x86_64.sh  sratoolkit.current-centos_linux64.tar.gz

# %% [markdown]
# ***The SRR numbers:***
# - SRR14999746
# - SRR14999747
# - SRR14999748
# - SRR14999749
# - SRR14999750
# - SRR14999751
# - SRR14999752
# - SRR14999753

# %%
cd /lustre1/project/stg_00079/students/soniya/data
ls
# Out:
# SRR14999746_1.fastq.gz	SRR14999748_1.fastq.gz	SRR14999750_1.fastq.gz
# SRR14999746_2.fastq.gz	SRR14999748_2.fastq.gz	SRR14999750_2.fastq.gz
# SRR14999747_1.fastq.gz	SRR14999749_1.fastq.gz	SRR14999752_1.fastq.gz
# SRR14999747_2.fastq.gz	SRR14999749_2.fastq.gz	SRR14999752_2.fastq.gz

# %%
cd /lustre1/project/stg_00079/students/soniya/data
ls -l
# Out:
# total 39374828
# -rw-rw----+ 1 vsc34524 ll_bdslab_student  444256681 Mar  6 21:16 SRR14999746_1.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student  991114758 Mar  6 21:16 SRR14999746_2.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student  445331779 Mar  6 21:36 SRR14999747_1.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student  982828809 Mar  6 21:36 SRR14999747_2.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student  777013725 Mar  6 22:13 SRR14999748_1.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student 1718621017 Mar  6 22:13 SRR14999748_2.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student 2064848298 Mar  7 10:44 SRR14999749_1.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student 4545118299 Mar  7 10:44 SRR14999749_2.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student 4364235819 Mar  7 14:02 SRR14999750_1.fastq.gz
# -rw-rw----+ 1 vsc34524 ll_bdslab_student 9524225353 Mar  7 14:02 SRR14999750_2.fastq.gz
# ...

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger/
ls
# Out:
# cellranger	  refdata-gex-mm10-2020-A
# cellranger-7.2.0  sratoolkit.3.1.0-centos_linux64

# %%
vdb-config -s /repository/user/cache-disabled=true
#This will prevent unnecessary files to be saved in your home folder, which has a strict quotum.

# %%
fastq-dump \
    SRR14999746 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 20352514 spots for SRR14999746
# Written 20352514 spots for SRR14999746

# %%
cat
# Out:
# analysis		       possorted_genome_bam.bam
# cloupe.cloupe		       possorted_genome_bam.bam.bai
# filtered_feature_bc_matrix     raw_feature_bc_matrix
# filtered_feature_bc_matrix.h5  raw_feature_bc_matrix.h5
# metrics_summary.csv	       web_summary.html
# molecule_info.h5

# %%
fastq-dump \
    SRR14999747 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 20400599 spots for SRR14999747
# Written 20400599 spots for SRR14999747

# %%
fastq-dump \
    SRR14999748 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 35474217 spots for SRR14999748
# Written 35474217 spots for SRR14999748

# %%
fastq-dump \
    SRR14999749 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 93342121 spots for SRR14999749
# Written 93342121 spots for SRR14999749

# %%
cd /lustre1/project/stg_00079/students/soniya/data
ls
# Out:
# SRR14999746_1.fastq.gz	SRR14999748_2.fastq.gz	SRR14999752_1.fastq.gz
# SRR14999746_2.fastq.gz	SRR14999749_1.fastq.gz	SRR14999752_2.fastq.gz
# SRR14999747_1.fastq.gz	SRR14999749_2.fastq.gz	SRR14999753_1.fastq.gz
# SRR14999747_2.fastq.gz	SRR14999750_1.fastq.gz	SRR14999753_2.fastq.gz
# SRR14999748_1.fastq.gz	SRR14999750_2.fastq.gz

# %%
ls
# Out:
# SRR14999746_1.fastq.gz	SRR14999748_1.fastq.gz	SRR14999752_1.fastq.gz
# SRR14999746_2.fastq.gz	SRR14999748_2.fastq.gz	SRR14999752_2.fastq.gz
# SRR14999747_1.fastq.gz	SRR14999749_1.fastq.gz
# SRR14999747_2.fastq.gz	SRR14999749_2.fastq.gz

# %%
cd /lustre1/project/stg_00079/students/soniya/data
ls
# Out:
# SRR14999746_1.fastq.gz	SRR14999747_1.fastq.gz	SRR14999748_1.fastq.gz
# SRR14999746_2.fastq.gz	SRR14999747_2.fastq.gz	SRR14999748_2.fastq.gz

# %%
fastq-dump \
    SRR14999750 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 195566423 spots for SRR14999750
# Written 195566423 spots for SRR14999750

# %%
fastq-dump \
    SRR14999751 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 101451704 spots for SRR14999751
# Written 101451704 spots for SRR14999751

# %%
ls
# Out:
# CellRanger.ipynb  Untitled.ipynb

# %%
fastq-dump \
    SRR14999752 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
# Out:
# Read 69556631 spots for SRR14999752
# Written 69556631 spots for SRR14999752

# %%
fastq-dump \
    SRR14999753 \
    --gzip \
    --split-files \
    --outdir /lustre1/project/stg_00079/students/soniya/data
    #still to do.
# Out:
# Read 134944221 spots for SRR14999753
# Written 134944221 spots for SRR14999753

# %% [markdown]
# # **CellRanger**

# %% [markdown]
# **(1) Rename all the SRR_ files according to CellRanger's requirements**

# %%
cd 
ls
# Out:
# bash: cd: data: No such file or directory
# SRR14999746_1.fastq.gz	SRR14999749_1.fastq.gz	SRR14999752_1.fastq.gz
# SRR14999746_2.fastq.gz	SRR14999749_2.fastq.gz	SRR14999752_2.fastq.gz
# SRR14999747_1.fastq.gz	SRR14999750_1.fastq.gz	SRR14999753_1.fastq.gz
# SRR14999747_2.fastq.gz	SRR14999750_2.fastq.gz	SRR14999753_2.fastq.gz
# SRR14999748_1.fastq.gz	SRR14999751_1.fastq.gz
# SRR14999748_2.fastq.gz	SRR14999751_2.fastq.gz

# %%
mv SRR14999746_1.fastq.gz SRR14999746_S21_L002_R1_001.fastq.gz

# %%
mv SRR14999746_2.fastq.gz SRR14999746_S21_L002_R2_001.fastq.gz

# %%
mv SRR14999747_1.fastq.gz SRR14999747_S22_L002_R1_001.fastq.gz

# %%
mv SRR14999747_2.fastq.gz SRR14999747_S22_L002_R2_001.fastq.gz

# %%
mv SRR14999748_1.fastq.gz SRR14999748_S23_L002_R1_001.fastq.gz

# %%
mv SRR14999748_2.fastq.gz SRR14999748_S23_L002_R2_001.fastq.gz

# %%
mv SRR14999749_1.fastq.gz SRR14999749_S24_L002_R1_001.fastq.gz

# %%
mv SRR14999749_2.fastq.gz SRR14999749_S24_L002_R2_001.fastq.gz

# %%
mv SRR14999750_1.fastq.gz SRR14999750_S25_L002_R1_001.fastq.gz

# %%
mv SRR14999750_2.fastq.gz SRR14999750_S25_L002_R2_001.fastq.gz

# %%
mv SRR14999751_1.fastq.gz SRR14999751_S26_L002_R1_001.fastq.gz

# %%
mv SRR14999751_2.fastq.gz SRR14999751_S26_L002_R2_001.fastq.gz

# %%
mv SRR14999752_1.fastq.gz SRR14999752_S27_L002_R1_001.fastq.gz

# %%
mv SRR14999752_2.fastq.gz SRR14999752_S27_L002_R2_001.fastq.gz

# %%
mv SRR14999753_1.fastq.gz SRR14999753_S28_L002_R1_001.fastq.gz

# %%
mv SRR14999753_2.fastq.gz SRR14999753_S28_L002_R2_001.fastq.gz

# %%
ls
# Out:
# SRR14999746_S21_L002_R1_001.fastq.gz  SRR14999750_S25_L002_R1_001.fastq.gz
# SRR14999746_S21_L002_R2_001.fastq.gz  SRR14999750_S25_L002_R2_001.fastq.gz
# SRR14999747_S22_L002_R1_001.fastq.gz  SRR14999751_S26_L002_R1_001.fastq.gz
# SRR14999747_S22_L002_R2_001.fastq.gz  SRR14999751_S26_L002_R2_001.fastq.gz
# SRR14999748_S23_L002_R1_001.fastq.gz  SRR14999752_S27_L002_R1_001.fastq.gz
# SRR14999748_S23_L002_R2_001.fastq.gz  SRR14999752_S27_L002_R2_001.fastq.gz
# SRR14999749_S24_L002_R1_001.fastq.gz  SRR14999753_S28_L002_R1_001.fastq.gz
# SRR14999749_S24_L002_R2_001.fastq.gz  SRR14999753_S28_L002_R2_001.fastq.gz

# %% [markdown]
# **(2) Install Cell Ranger, download the mouse reference**

# %%
# i already downloaded the cell ranger and the mouse reference genome, now i have to unzip them: 
tar -xf cellranger-7.2.0.tar.gz

# %%
tar -xf  refdata-gex-mm10-2020-A.tar.gz

# %%
mkdir -p results/cellranger # make directory with all the cellranger files.

# %%
cd /lustre1/project/stg_00079/students/soniya/
mkdir -p data
ls
# Out:
# cellranger-7.2.0	 Miniforge3-Linux-x86_64.sh	 results
# cellranger-7.2.0.tar.gz  refdata-gex-mm10-2020-A
# data			 refdata-gex-mm10-2020-A.tar.gz

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger
ls
# Out:
# cellranger	  refdata-gex-mm10-2020-A
# cellranger-7.2.0  sratoolkit.3.1.0-centos_linux64

# %% [markdown]
# **(3) Run Cell Ranger**

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger/
ls
rm -r
# Out:
# cellranger	  refdata-gex-mm10-2020-A	   T1  T3  T5
# cellranger-7.2.0  sratoolkit.3.1.0-centos_linux64  T2  T4

# %%
cellranger-7.2.0/cellranger count \
    --id=T1 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999746 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:38485?auth=o-tk4BOXgvl9bx5B5FuvtPfypkn1dxaDZGVQ_9PjMSs
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-08 15:56:03 [runtime] (ready)           ID.T1.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MULTI_CHEMISTRY_DETECTOR.DETECT_COUNT_CHEMISTRY
# 2024-03-08 15:56:03 [runtime] (run:local)       ID.T1.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MULTI_CHEMISTRY_DETECTOR.DETECT_COUNT_CHEMISTRY.fork0.chnk0.main
# 2024-03-08 15:56:03 [runtime] (ready)           ID.T1.SC_RNA_COUNTER_CS.SC_MULTI_CORE.SANITIZE_MAP_CALLS
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T2 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999747 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:39155?auth=qMvV6aW6-vTkOi7bME5BCbz5hetHXhbuCxmhbRYyriA
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-08 16:13:30 [runtime] (ready)           ID.T2.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MAKE_FULL_CONFIG._MAKE_VDJ_CONFIG
# 2024-03-08 16:13:30 [runtime] (run:local)       ID.T2.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MAKE_FULL_CONFIG._MAKE_VDJ_CONFIG.fork0.chnk0.main
# 2024-03-08 16:13:30 [runtime] (ready)           ID.T2.SC_RNA_COUNTER_CS.SC_MULTI_CORE.SANITIZE_MAP_CALLS
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T3 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999748 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:33177?auth=rTGVuKuB1KIdb4eEMLskSYA9jLilfBT2qkoJI2SumBk
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-09 00:31:04 [runtime] (ready)           ID.T3.SC_RNA_COUNTER_CS.FULL_COUNT_INPUTS.WRITE_GENE_INDEX
# 2024-03-09 00:31:04 [runtime] (run:local)       ID.T3.SC_RNA_COUNTER_CS.FULL_COUNT_INPUTS.WRITE_GENE_INDEX.fork0.chnk0.main
# 2024-03-09 00:31:04 [runtime] (ready)           ID.T3.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MULTI_CHEMISTRY_DETECTOR.DETECT_COUNT_CHEMISTRY
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T4 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999749 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:40127?auth=8t_MlIXSOKBiIQY6XTlsgp9aiJB1olIX0yWFHFod3T0
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-08 16:30:30 [runtime] (ready)           ID.T4.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MAKE_FULL_CONFIG._MAKE_VDJ_CONFIG
# 2024-03-08 16:30:30 [runtime] (run:local)       ID.T4.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MAKE_FULL_CONFIG._MAKE_VDJ_CONFIG.fork0.chnk0.main
# 2024-03-08 16:30:30 [runtime] (ready)           ID.T4.SC_RNA_COUNTER_CS.WRITE_GENE_INDEX
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T5 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999750 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:39433?auth=KuyjB-5OX-iU2VZtY9Yi87s8dcy29aDB-51drA2auDo
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-09 00:55:32 [runtime] (ready)           ID.T5.SC_RNA_COUNTER_CS.FULL_COUNT_INPUTS.WRITE_GENE_INDEX
# 2024-03-09 00:55:32 [runtime] (run:local)       ID.T5.SC_RNA_COUNTER_CS.FULL_COUNT_INPUTS.WRITE_GENE_INDEX.fork0.chnk0.main
# 2024-03-09 00:55:32 [runtime] (ready)           ID.T5.SC_RNA_COUNTER_CS.WRITE_GENE_INDEX
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T6 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999751 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:45303?auth=36NVx85mx_9zF5sBeFul33arOJQ1htkS-s59BuI_Lh8
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-09 03:10:06 [runtime] (ready)           ID.T6.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MULTI_CHEMISTRY_DETECTOR.DETECT_COUNT_CHEMISTRY
# 2024-03-09 03:10:06 [runtime] (run:local)       ID.T6.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MULTI_CHEMISTRY_DETECTOR.DETECT_COUNT_CHEMISTRY.fork0.chnk0.main
# 2024-03-09 03:10:06 [runtime] (ready)           ID.T6.SC_RNA_COUNTER_CS.WRITE_GENE_INDEX
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T7 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999752 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:33543?auth=zrAu_YVx4re8ez7Q2Gv3Hf_SUpesA07OdN2EPmyXgC0
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-09 04:01:53 [runtime] (ready)           ID.T7.SC_RNA_COUNTER_CS.SC_MULTI_CORE.SANITIZE_MAP_CALLS
# 2024-03-09 04:01:53 [runtime] (ready)           ID.T7.SC_RNA_COUNTER_CS.WRITE_GENE_INDEX
# 2024-03-09 04:01:53 [runtime] (run:local)       ID.T7.SC_RNA_COUNTER_CS.WRITE_GENE_INDEX.fork0.chnk0.main
# ...

# %%
cellranger-7.2.0/cellranger count \
    --id=T8 \
    --transcriptome=/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ \
    --fastqs=/lustre1/project/stg_00079/students/soniya/data/ \
    --sample=SRR14999753 \
    --localcores=8 \
    --localmem=24
# Out:
# Martian Runtime - v4.0.11
# Serving UI at http://k28i14:43353?auth=vljFeeSBjD9Qx2RGv-Sp-qVgbtB7eym9k-z6XmiBKIk
#
# Running preflight checks (please wait)...
# Checking sample info...
# Checking FASTQ folder...
# Checking reference...
# Checking reference_path (/lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A) on k28i14...
# Checking optional arguments...
# mro: v4.0.11
# mrp: v4.0.11
# Anaconda: Python 3.10.11
# numpy: 1.24.3
# scipy: 1.10.1
# pysam: 0.21.0
# h5py: 3.6.0
# pandas: 1.5.3
# STAR: 2.7.2a
# samtools: samtools 1.16.1
# 2024-03-09 04:37:58 [runtime] (ready)           ID.T8.SC_RNA_COUNTER_CS.SC_MULTI_CORE.SPLIT_VDJ_INPUTS
# 2024-03-09 04:37:58 [runtime] (ready)           ID.T8.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MAKE_FULL_CONFIG._MAKE_VDJ_CONFIG
# 2024-03-09 04:37:58 [runtime] (run:local)       ID.T8.SC_RNA_COUNTER_CS.SC_MULTI_CORE.MAKE_FULL_CONFIG._MAKE_VDJ_CONFIG.fork0.chnk0.main
# ...

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger/refdata-gex-mm10-2020-A/ 
ls
# Out:
# fasta  genes  pickle  reference.json  star

# %%
ls
# Out:
# cellranger	  refdata-gex-mm10-2020-A	   T1  T3  T5  T7
# cellranger-7.2.0  sratoolkit.3.1.0-centos_linux64  T2  T4  T6  T8

# %% [markdown]
#   **from fastq to the count output files**

# %%
mv /lustre1/project/stg_00079/students/soniya/refdata-gex-mm10-2020-A /lustre1/project/stg_00079/students/soniya/all_cell_ranger

# %%
mv /lustre1/project/stg_00079/students/soniya/sratoolkit.3.1.0-centos_linux64 /lustre1/project/stg_00079/students/soniya/all_cell_ranger

# %%
cd  /lustre1/project/stg_00079/students/soniya/all_cell_ranger/results/T1
#go to T1. 
ls
# Out:
# _cmdline     _invocation  _mrosource  SC_RNA_COUNTER_CS  _tags	     _vdrkill
# _filelist    _jobmode	  outs	      _sitecheck	 _timestamp  _versions
# _finalstate  _log	  _perf       T1.mri.tgz	 _uuid

# %%
Now we go to "Outs" to check the wanted output files.

# %%
cd  /lustre1/project/stg_00079/students/soniya/all_cell_ranger/

# %%
ls
# Out:
# cellranger	  refdata-gex-mm10-2020-A  sratoolkit.3.1.0-centos_linux64
# cellranger-7.2.0  results

# %%
cd  /lustre1/project/stg_00079/students/soniya/all_cell_ranger/T1/outs
ls
# Out:
# analysis		       possorted_genome_bam.bam
# cloupe.cloupe		       possorted_genome_bam.bam.bai
# filtered_feature_bc_matrix     raw_feature_bc_matrix
# filtered_feature_bc_matrix.h5  raw_feature_bc_matrix.h5
# metrics_summary.csv	       web_summary.html
# molecule_info.h5

# %%
pwd
# Out:
# /vsc-hard-mounts/leuven-data/345/vsc34524/MasterThesis

# %%
cd /lustre1/project/stg_00079/students/soniya/data
ls
# Out:
# SRR14999746_S21_L002_R1_001.fastq.gz  SRR14999750_S25_L002_R1_001.fastq.gz
# SRR14999746_S21_L002_R2_001.fastq.gz  SRR14999750_S25_L002_R2_001.fastq.gz
# SRR14999747_S22_L002_R1_001.fastq.gz  SRR14999751_S26_L002_R1_001.fastq.gz
# SRR14999747_S22_L002_R2_001.fastq.gz  SRR14999751_S26_L002_R2_001.fastq.gz
# SRR14999748_S23_L002_R1_001.fastq.gz  SRR14999752_S27_L002_R1_001.fastq.gz
# SRR14999748_S23_L002_R2_001.fastq.gz  SRR14999752_S27_L002_R2_001.fastq.gz
# SRR14999749_S24_L002_R1_001.fastq.gz  SRR14999753_S28_L002_R1_001.fastq.gz
# SRR14999749_S24_L002_R2_001.fastq.gz  SRR14999753_S28_L002_R2_001.fastq.gz

# %%
ls
# Out:
# all_cell_ranger  Miniforge3-Linux-x86_64.sh  Supplementary_Code.rmd
# data		 R-3.6.3.tar.gz		     vsc34524

# %%
cd
# Out:
# antwerpen  brussel  gent  leuven

# %%
R
# Out:
# R version 4.3.2 (2023-10-31) -- "Eye Holes"
# Copyright (C) 2023 The R Foundation for Statistical Computing
# Platform: x86_64-redhat-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.

# %%
cd /lustre1/project/stg_00079/students/soniya
ls
# Out:
# all_cell_ranger  data

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger/cellranger

# %%
cd /lustre1/project/stg_00079/students/soniya/all_cell_ranger/results

# %%
ls
# Out:
# T1  T2	T3  T4	T5  T6	T7  T8

# %%
cd T1
ls
# Out:
# bash: cd: T1: No such file or directory
# _cmdline     _invocation  _mrosource  SC_RNA_COUNTER_CS  _tags	     _vdrkill
# _filelist    _jobmode	  outs	      _sitecheck	 _timestamp  _versions
# _finalstate  _log	  _perf       T1.mri.tgz	 _uuid

# %%
ls
# Out:
# analysis		       possorted_genome_bam.bam
# cloupe.cloupe		       possorted_genome_bam.bam.bai
# filtered_feature_bc_matrix     raw_feature_bc_matrix
# filtered_feature_bc_matrix.h5  raw_feature_bc_matrix.h5
# metrics_summary.csv	       web_summary.html
# molecule_info.h5

# %% [markdown]
# analysis - The results of clustering and differential expression analysis on the clusters. These are used in the web_summary.html report.
#
# cloupe.cloupe - a cloupe file for loading into the 10x loupe browser
#
# **filtered_feature_bc_matrix - The filtered count matrix directory**
#
# filtered_feature_bc_matrix.h5 - The filtered count matrix as an HDF5 file
#
# metrics_summary.csv - summary metrics from the analysis
#
# molecule_info.h5 - per-molecule read information as an HDF5 file
#
# possorted_genome_bam.bam - The aligned reads in bam format
#
# possorted_genome_bam.bam.bai - The bam index
#
# **raw_feature_bc_matrix - The raw count matrix directory**
#
# raw_feature_bc_matrix.h5 - The raw count matrix as an HDF5 file
#
# web_summary.html - The summary report

# %% [markdown]
# # **Do Seurat first, then check the outputs of CellRanger**:
# 1) What input does Seurat need?
# 2) Understand the outputs of CellRanger.
